# %% [markdown]
# # Pandas

# %%
# Importar pandas
import pandas as pd

# %%
dict_df = {
    "Campañas": ["test1", "test2", "test3", "test4"],
    "Costo": [100.1, 200.4, 300.5, 400.48],
    "Impresiones": [1000, 2000, 3000, 4000]
}

# %%
type(dict_df)
# Out:
# dict

# %%
pd.DataFrame(dict_df)
# Out:
#   Campañas   Costo  Impresiones
# 0    test1  100.10         1000
# 1    test2  200.40         2000
# 2    test3  300.50         3000
# 3    test4  400.48         4000

# %%
df = pd.DataFrame(dict_df)

# %%
df["CPM"] = df["Costo"] / df["Impresiones"] * 1000

# %%
df
# Out:
#   Campañas   Costo  Impresiones         CPM
# 0    test1  100.10         1000  100.100000
# 1    test2  200.40         2000  100.200000
# 2    test3  300.50         3000  100.166667
# 3    test4  400.48         4000  100.120000
